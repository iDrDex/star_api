# %%
from analysis import perform_analysis
from easydict import EasyDict
# Out:
# /Users/dex/anaconda/lib/python2.7/site-packages/pandas/rpy/__init__.py:11: FutureWarning: The pandas.rpy module is deprecated and will be removed in a future version. We refer to external packages like rpy2.
# See here for a guide on how to port your code to rpy2: http://pandas.pydata.org/pandas-docs/stable/r_interface.html
#   FutureWarning)

# %%
analysis = EasyDict(
        analysis_name = "test",
        case_query = """ MS == 'MS'""",
        control_query = """MS_control == 'MS_control'""",
        modifier_query = "",
        min_samples = 3
    )

# %%
    analysis = EasyDict(
        analysis_name = "test",
        case_query = """Smoker == 'Smoker'""",# MS == 'MS'""",
        control_query = """Nonsmoker == 'Nonsmoker'""",#"""MS_control == 'MS_control'""",
        modifier_query = "",
        min_samples = 3
    )

# %%
analysis = perform_analysis(analysis=analysis)
analysis.to_csv("analysis.csv")
# Out:
# Started test analysis
# INFO:analysis:Started test analysis
# /Users/dex/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 435.81 ms in get_analysis_df("Smoker == 'Smoker'", "Nonsmoker == 'Nonsmok..., '')
# DEBUG:analysis:435.81 ms in get_analysis_df("Smoker == 'Smoker'", "Nonsmoker == 'Nonsmok..., '')
# 437.12 ms in Loading dataframe for test
# DEBUG:analysis:437.12 ms in Loading dataframe for test
# Matching sources: 21
# INFO:analysis:Matching sources: 21
# Excluded 2 sources as single-class
# INFO:analysis:Excluded 2 sources as single-class
# Stats: 19 sources, 17 series, 6 platforms, 1423 samples
# INFO:analysis:Stats: 19 sources, 17 series, 6 platforms, 1423 samples
# Loading data and calculating fold changes for test
# INFO:analysis:Loading data and calculating fold changes for test
# Loading data for GSE10006, id = 4
# DEBUG:analysis:Loading data for GSE10006, id = 4
#   1.96 s in get_data(4, 4)
# DEBUG:analysis:  1.96 s in get_data(4, 4)
# 709.42 ms in get_probes(4)
# DEBUG:analysis:709.42 ms in get_probes(4)
#   2.75 s in load_gse( series_id platform_id..., 4)
# DEBUG:analysis:  2.75 s in load_gse( series_id platform_id..., 4)
# analysis.py:360: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   samples['subset'] = "NA"
#   1.23 s in get_fold_change_analysis(<Gse GSE10006>)
# DEBUG:analysis:  1.23 s in get_fold_change_analysis(<Gse GSE10006>)
# Loading data for GSE11784, id = 450
# DEBUG:analysis:Loading data for GSE11784, id = 450
#   3.42 s in get_data(450, 4)
# DEBUG:analysis:  3.42 s in get_data(450, 4)
# 672.60 ms in get_probes(4)
# DEBUG:analysis:672.60 ms in get_probes(4)
#   4.16 s in load_gse( series_id platform_id..., 450)
# DEBUG:analysis:  4.16 s in load_gse( series_id platform_id..., 450)
#  47.11 ms in get_fold_change_analysis(<Gse GSE11784>)
# DEBUG:analysis: 47.11 ms in get_fold_change_analysis(<Gse GSE11784>)
#   8.26 s in Load/fold for test
# DEBUG:analysis:  8.26 s in Load/fold for test
#   8.73 s in perform_analysis(analysis={'analysis_name': 'tes...)
# DEBUG:analysis:  8.73 s in perform_analysis(analysis={'analysis_name': 'tes...)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-445e3a8bbebe> in <module>()
# ----> 1 analysis = perform_analysis(analysis=analysis)
#       2 analysis.to_csv("analysis.csv")
#
# /Users/dex/anaconda/lib/python2.7/site-packages/funcy/debug.pyc in inner(*args, **kwargs)
#      95             cm.label = signature_repr(Call(func, args, kwargs))
#      96             with cm:
# ---> 97                 return func(*args, **kwargs)
#      98         return inner
#      99
#
# /Users/dex/Copy/Code/star_api/analysis.py in perform_analysis(analysis, debug)
#      68     with log_durations(logger.debug, 'Load/fold for %s' % analysis.analysis_name):
#      69         gses = (load_gse(df, series_id) for series_id in sorted(df.series_id.unique()))
# ---> 70         fold_changes = pd.concat(imap(get_fold_change_analysis, gses))
#      71         debug and fold_changes.to_csv("%s.fc.csv" % debug)
#      72
#
# /Users/dex/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#     752                        keys=keys, levels=levels, names=names,
#     753                        verify_integrity=verify_integrity,
# --> 754                        copy=copy)
#     755     return op.get_result()
#     756
#
# /Users/dex/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
#     783
#     784         if keys is None:
# --> 785             objs = [obj for obj in objs if obj is not None ]
#     786         else:
#     787             # #1649
#
# /Users/dex/anaconda/lib/python2.7/site-packages/funcy/debug.pyc in inner(*args, **kwargs)
#      95             cm.label = signature_repr(Call(func, args, kwargs))
#      96             with cm:
# ---> 97                 return func(*args, **kwargs)
#      98         return inner
#      99
#
# /Users/dex/Copy/Code/star_api/analysis.py in get_fold_change_analysis(gse)
#     110 def get_fold_change_analysis(gse):
#     111     # TODO: get rid of unneeded OOP interface
# --> 112     return GseAnalyzer(gse).getResults(debug=False)
#     113
#     114
#
# /Users/dex/Copy/Code/star_api/analysis.py in getResults(self, debug)
#     385             debug = debug and debug + ".%s_%s_%s" % (self.gse.name, gpl, subset)
#     386             table = getFoldChangeAnalysis(data, sample_class,
# --> 387                                           debug=debug)
#     388             debug and table.to_csv("%s.table.csv" % debug)
#     389
#
# /Users/dex/Copy/Code/star_api/analysis.py in getFoldChangeAnalysis(data, sample_class, debug)
#     577     from scipy.stats import ttest_ind
#     578
# --> 579     data = normalize_quantiles(log_data(data))
#     580
#     581     summary = pd.DataFrame(index=data.index)
#
# /Users/dex/Copy/Code/star_api/main.pyc in log_data(df)
#     227
#     228 def log_data(df):
# --> 229     if is_logged(df):
#     230         return df
#     231
#
# /Users/dex/Copy/Code/star_api/main.pyc in is_logged(df)
#     236
#     237 def is_logged(df):
# --> 238     return np.max(df.values) < 10
#     239
#     240 # def is_logged(data):
#
# /Users/dex/anaconda/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in amax(a, axis, out, keepdims)
#    2138     else:
#    2139         return _methods._amax(a, axis=axis,
# -> 2140                             out=out, keepdims=keepdims)
#    2141
#    2142 def amin(a, axis=None, out=None, keepdims=False):
#
# /Users/dex/anaconda/lib/python2.7/site-packages/numpy/core/_methods.pyc in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %%
# ?Gse
# Out:
# Object `Gse` not found.

# %%
from main import *
# Out:
# /Users/dex/anaconda/lib/python2.7/site-packages/pandas/rpy/__init__.py:11: FutureWarning: The pandas.rpy module is deprecated and will be removed in a future version. We refer to external packages like rpy2.
# See here for a guide on how to port your code to rpy2: http://pandas.pydata.org/pandas-docs/stable/r_interface.html
#   FutureWarning)

# %%
data = get_data(450, 4)
# Out:
# Cluster size 54675 broken into 53074 1601
# Cluster size 53074 broken into 46582 6492
# Cluster size 46582 broken into 37469 9113
# Cluster size 37469 broken into 8536 28933
# Cluster size 8536 broken into 8232 304
# Cluster size 8232 broken into 3581 4651
# Cluster size 3581 broken into 2355 1226
# Cluster size 2355 broken into 702 1653
# Done cluster 702
# Cluster size 1653 broken into 883 770
# Done cluster 883
# Done cluster 770
# Done cluster 1653
# Done cluster 2355
# Done cluster 1226
# Done cluster 3581
# Cluster size 4651 broken into 2473 2178
# Cluster size 2473 broken into 1607 866
# Cluster size 1607 broken into 996 611
# Done cluster 996
# Done cluster 611
# Done cluster 1607
# Done cluster 866
# Done cluster 2473
# Cluster size 2178 broken into 1353 825
# Done cluster 1353
# Done cluster 825
# Done cluster 2178
# Done cluster 4651
# Done cluster 8232
# Done cluster 304
# Done cluster 8536
# Cluster size 28933 broken into 8608 20325
# Cluster size 8608 broken into 5106 3502
# Cluster size 5106 broken into 3130 1976
# Cluster size 3130 broken into 1861 1269
# Cluster size 1861 broken into 501 1360
# Done cluster 501
# Done cluster 1360
# Done cluster 1861
# Done cluster 1269
# Done cluster 3130
# Cluster size 1976 broken into 637 1339
# Done cluster 637
# Done cluster 1339
# Done cluster 1976
# Done cluster 5106
# Cluster size 3502 broken into 2021 1481
# Cluster size 2021 broken into 1487 534
# Done cluster 1487
# Done cluster 534
# Done cluster 2021
# Done cluster 1481
# Done cluster 3502
# Done cluster 8608
# Cluster size 20325 broken into 7748 12577
# Cluster size 7748 broken into 4208 3540
# Cluster size 4208 broken into 2547 1661
# Cluster size 2547 broken into 1162 1385
# Done cluster 1162
# Done cluster 1385
# Done cluster 2547
# Cluster size 1661 broken into 638 1023
# Done cluster 638
# Done cluster 1023
# Done cluster 1661
# Done cluster 4208
# Cluster size 3540 broken into 3495 45
# Cluster size 3495 broken into 1630 1865
# Cluster size 1630 broken into 760 870
# Done cluster 760
# Done cluster 870
# Done cluster 1630
# Cluster size 1865 broken into 793 1072
# Done cluster 793
# Done cluster 1072
# Done cluster 1865
# Done cluster 3495
# Done cluster 45
# Done cluster 3540
# Done cluster 7748
# Cluster size 12577 broken into 5781 6796
# Cluster size 5781 broken into 16 5765
# Done cluster 16
# Cluster size 5765 broken into 2188 3577
# Cluster size 2188 broken into 865 1323
# Done cluster 865
# Done cluster 1323
# Done cluster 2188
# Cluster size 3577 broken into 1267 2310
# Done cluster 1267
# Cluster size 2310 broken into 1150 1160
# Done cluster 1150
# Done cluster 1160
# Done cluster 2310
# Done cluster 3577
# Done cluster 5765
# Done cluster 5781
# Cluster size 6796 broken into 3719 3077
# Cluster size 3719 broken into 1800 1919
# Cluster size 1800 broken into 485 1315
# Done cluster 485
# Done cluster 1315
# Done cluster 1800
# Cluster size 1919 broken into 1301 618
# Done cluster 1301
# Done cluster 618
# Done cluster 1919
# Done cluster 3719
# Cluster size 3077 broken into 320 2757
# Done cluster 320
# Cluster size 2757 broken into 2401 356
# Cluster size 2401 broken into 1165 1236
# Done cluster 1165
# Done cluster 1236
# Done cluster 2401
# Done cluster 356
# Done cluster 2757
# Done cluster 3077
# Done cluster 6796
# Done cluster 12577
# Done cluster 20325
# Done cluster 28933
# Done cluster 37469
# Cluster size 9113 broken into 5507 3606
# Cluster size 5507 broken into 1811 3696
# Cluster size 1811 broken into 3 1808
# Done cluster 3
# Cluster size 1808 broken into 1734 74
# Cluster size 1734 broken into 1036 698
# Done cluster 1036
# Done cluster 698
# Done cluster 1734
# Done cluster 74
# Done cluster 1808
# Done cluster 1811
# Cluster size 3696 broken into 1238 2458
# Done cluster 1238
# Cluster size 2458 broken into 941 1517
# Done cluster 941
# Cluster size 1517 broken into 2 1515
# Done cluster 2
# Cluster size 1515 broken into 10 1505
# Done cluster 10
# Cluster size 1505 broken into 879 626
# Done cluster 879
# Done cluster 626
# Done cluster 1505
# Done cluster 1515
# Done cluster 1517
# Done cluster 2458
# Done cluster 3696
# Done cluster 5507
# Cluster size 3606 broken into 1500 2106
# Done cluster 1500
# Cluster size 2106 broken into 1185 921
# Done cluster 1185
# Done cluster 921
# Done cluster 2106
# Done cluster 3606
# Done cluster 9113
# Done cluster 46582
# Cluster size 6492 broken into 4490 2002
# Cluster size 4490 broken into 2638 1852
# Cluster size 2638 broken into 1621 1017
# Cluster size 1621 broken into 1615 6
# Cluster size 1615 broken into 709 906
# Done cluster 709
# Done cluster 906
# Done cluster 1615
# Done cluster 6
# Done cluster 1621
# Done cluster 1017
# Done cluster 2638
# Cluster size 1852 broken into 1219 633
# Done cluster 1219
# Done cluster 633
# Done cluster 1852
# Done cluster 4490
# Cluster size 2002 broken into 1313 689
# Done cluster 1313
# Done cluster 689
# Done cluster 2002
# Done cluster 6492
# Done cluster 53074
# Cluster size 1601 broken into 1259 342
# Done cluster 1259
# Done cluster 342
# Done cluster 1601

# %%
data
# Out:
# gsm_name               GSM101096  GSM101097  GSM101098  GSM101100  GSM101101  \
# probe
# 1007_s_at              10.700661  11.132508  10.533451  11.312544  10.939073
# 1053_at                 6.356907   6.392209   5.948021   6.428239   6.761448
# 117_at                  6.395944   5.112460   5.194430   5.084438   4.974640
# 121_at                  7.492750   7.533521   7.160711   7.308308   7.458859
# 1255_g_at               4.034575   4.224225   3.992968   4.038973   4.043961
# 1294_at                 8.044043   8.047619   8.140571   8.113527   7.730581
# 1316_at                 5.679523   6.021871   5.705937   5.853718   5.628136
# 1320_at                 5.431607   5.630469   5.188642   5.541226   5.541157
# 1405_i_at               8.748535   7.095934   6.913766   7.035671   6.078483
# 1431_at                 4.429381   4.393920   4.575821   4.212165   4.592305
# 1438_at                 6.218071   6.176389   6.160135   6.576977   5.893819
# 1487_at                 7.230745   7.400634   7.246037   7.510976   7.311633
# 1494_f_at               6.868507   6.870195   6.843277   6.855051   7.213603
# AFFX-r2-Bs-dap-3_at     2.179689   2.528998   1.769329   2.083732   1.472521
# AFFX-r2-Bs-dap-5_at     1.917179   2.159686   1.494745   2.669921   1.883333
# AFFX-r2-Bs-dap-M_at     1.075193   2.598116   4.840243   5.193864   2.125355
# AFFX-r2-Bs-lys-3_at     5.516915   4.621403   5.524826   4.489501   5.109537
# AFFX-r2-Bs-lys-5_at     3.301666   4.435084   2.796630   2.555646   1.340844
# AFFX-r2-Bs-lys-M_at     1.575587   1.377205   2.576680   5.046873   5.727499
# AFFX-r2-Bs-phe-3_at     5.333074   2.998233   6.732390   6.392249   6.491056
# AFFX-r2-Bs-phe-5_at     4.942366   4.840571   2.989568   1.797517   1.475632
# AFFX-r2-Bs-phe-M_at     2.627037   3.750074   3.379511   4.896148   1.572300
# AFFX-r2-Bs-thr-3_s_at   3.012250   4.324943   3.811516   5.409280   4.625973
# AFFX-r2-Bs-thr-5_s_at   3.563932   4.221833   6.657873   6.511273   6.122969
# AFFX-r2-Bs-thr-M_s_at   5.161035   2.831058   6.435641   3.819816   4.251198
# AFFX-r2-Ec-bioB-3_at   10.444134  10.822929  11.090974  11.378105  11.230557
# AFFX-r2-Ec-bioB-5_at   10.539342  10.832257  11.302640  11.585141  11.576547
# AFFX-r2-Ec-bioB-M_at   10.538295  10.961631  11.381225  11.453024  11.509643
# AFFX-r2-Ec-bioC-3_at   12.074061  12.309238  12.641095  12.865395  13.050836
# AFFX-r2-Ec-bioC-5_at   11.680790  11.837190  12.263610  12.505219  12.767136
# AFFX-r2-Ec-bioD-3_at   14.070035  14.291315  14.803300  15.067552  15.062116
# AFFX-r2-Ec-bioD-5_at   13.686247  13.948167  14.452133  14.729515  14.736970
# AFFX-r2-P1-cre-3_at    15.941494  16.056251  16.339395  16.655047  16.636317
# AFFX-r2-P1-cre-5_at    15.515844  15.610979  15.899634  16.263256  16.196759
# AFFX-ThrX-3_at          3.292075   3.455687   4.545631   5.250114   2.791554
# AFFX-ThrX-5_at          4.282250   2.748289   5.538021   2.395072   3.259659
# AFFX-ThrX-M_at          2.238517   3.722186   4.062133   3.497185   4.007914
# AFFX-TrpnX-3_at         2.645042   2.784842   3.069708   2.405340   4.702653
# AFFX-TrpnX-5_at         5.648300   5.244675   6.175936   4.350713   5.466239
# AFFX-TrpnX-M_at         2.459651   2.705022   3.141800   2.636445   2.628156
#
# gsm_name               GSM470013
# probe
# 1007_s_at              13.106155
# 1053_at                 7.988830
# 117_at                  5.463167
# 121_at                  8.698453
# 1255_g_at               5.196743
# 1294_at                10.033091
# 1316_at                 8.021272
# 1320_at                 5.991013
# 1405_i_at               9.260394
# 1431_at                 5.810206
# 1438_at                 7.245426
# 1487_at                 9.898244
# 1494_f_at               8.161725
# 1552256_a_at            8.460340
# 1552257_a_at            9.403088
# 1552258_at              6.839628
# 1552261_at              9.600286
# 1552263_at              7.842845
# 1552264_a_at            8.676541
# 1552266_at              2.539230
# 1552269_at             10.165320
# 1552271_at              4.242371
# 1552272_a_at            7.226072
# 1552274_at              8.964842
# 1552275_s_at            6.484300
# 1552276_a_at            4.567306
# 1552277_a_at            8.212607
# 1552278_a_at            7.335923
# 1552279_a_at            8.390984
# 1552280_at              4.124375
# ...                          ...
# AFFX-PheX-3_at          5.995950
# AFFX-PheX-5_at          4.475303
# AFFX-PheX-M_at          2.675427
# AFFX-r2-Bs-dap-3_at     2.393844
# AFFX-r2-Bs-dap-5_at     1.541246
# AFFX-r2-Bs-dap-M_at     1.805399
# AFFX-r2-Bs-lys-3_at     4.548206
# AFFX-r2-Bs-lys-5_at     5.191257
# AFFX-r2-Bs-lys-M_at     2.667614
# AFFX-r2-Bs-phe-3_at     6.066736
# AFFX-r2-Bs-phe-5_at     5.185968
# AFFX-r2-Bs-phe-M_at     2.246155
# AFFX-r2-Bs-thr-3_s_at   3.393044
# AFFX-r2-Bs-thr-5_s_at   6.210784
# AFFX-r2-Bs-thr-M_s_at   3.146311
# AFFX-r2-Ec-bioB-3_at   10.904679
# AFFX-r2-Ec-bioB-5_at   11.220656
# AFFX-r2-Ec-bioB-M_at   11.178988
# AFFX-r2-Ec-bioC-3_at   12.596287
# AFFX-r2-Ec-bioC-5_at   12.244497
# AFFX-r2-Ec-bioD-3_at   14.687066
# AFFX-r2-Ec-bioD-5_at   14.278227
# AFFX-r2-P1-cre-3_at    16.249822
# AFFX-r2-P1-cre-5_at    15.816032
# AFFX-ThrX-3_at          3.043260
# AFFX-ThrX-5_at          4.766938
# AFFX-ThrX-M_at          4.830675
# AFFX-TrpnX-3_at         3.974416
# AFFX-TrpnX-5_at         5.700833
# AFFX-TrpnX-M_at         1.967699
#
# [54675 rows x 157 columns]

# %%
from analysis import *
probes = get_probes(4)
# Out:
#   1.50 s in get_probes(4)
# DEBUG:analysis:  1.50 s in get_probes(4)

# %%
data = pd.read_csv("data.csv")

# %%
data = normalize_quantiles(log_data(data))

# %%
data
# Out:
# Empty DataFrame
# Columns: [probe, GSM101096, GSM101097, GSM101098, GSM101100, GSM101101, GSM101102, GSM101103, GSM101104, GSM101105, GSM101106, GSM101107, GSM101111, GSM101113, GSM101114, GSM101115, GSM101116, GSM114089, GSM114090, GSM114093, GSM190149, GSM190150, GSM190151, GSM190153, GSM190154, GSM190155, GSM190156, GSM252828, GSM252830, GSM252831, GSM252833, GSM252835, GSM252836, GSM252837, GSM252838, GSM252839, GSM252841, GSM252855, GSM252867, GSM252871, GSM252876, GSM252879, GSM252880, GSM252881, GSM252882, GSM252884, GSM252885, GSM254149, GSM254150, GSM254151, GSM254152, GSM254157, GSM254158, GSM254159, GSM254160, GSM254161, GSM254163, GSM254169, GSM254172, GSM254173, GSM254174, GSM254175, GSM254176, GSM298219, GSM298220, GSM298221, GSM298222, GSM298223, GSM298224, GSM298225, GSM298226, GSM298227, GSM298228, GSM298229, GSM298230, GSM298231, GSM298232, GSM298233, GSM298234, GSM298235, GSM298236, GSM298237, GSM298238, GSM298239, GSM298240, GSM298241, GSM298242, GSM298243, GSM298244, GSM298245, GSM298246, GSM298247, GSM300859, GSM302396, GSM302397, GSM302399, GSM350871, GSM350873, GSM350874, GSM350955, ...]
# Index: []
#
# [0 rows x 158 columns]
