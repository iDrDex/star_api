# %%
from analysis import perform_analysis
from easydict import EasyDict

analysis = EasyDict(
        analysis_name = "test",
        case_query = """ MS == 'MS'""",
        control_query = """MS_control == 'MS_control'""",
        modifier_query = "",
        min_samples = 3
    )
analysis = perform_analysis(analysis=analysis)
analysis.to_csv("analysis.csv")
# Out:
# Started test analysis
# INFO:analysis:Started test analysis
# /Users/dex/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 576.96 ms in get_analysis_df(" MS == 'MS'", "MS_control == 'MS_con..., '')
# DEBUG:analysis:576.96 ms in get_analysis_df(" MS == 'MS'", "MS_control == 'MS_con..., '')
# 577.99 ms in Loading dataframe for test
# DEBUG:analysis:577.99 ms in Loading dataframe for test
# Matching sources: 27
# INFO:analysis:Matching sources: 27
# Excluded 3 sources as single-class
# INFO:analysis:Excluded 3 sources as single-class
# Excluded 2 sources by min samples
# INFO:analysis:Excluded 2 sources by min samples
# Stats: 22 sources, 21 series, 9 platforms, 1781 samples
# INFO:analysis:Stats: 22 sources, 21 series, 9 platforms, 1781 samples
# Loading data and calculating fold changes for test
# INFO:analysis:Loading data and calculating fold changes for test
# Loading data for GSE10064, id = 17
# DEBUG:analysis:Loading data for GSE10064, id = 17
# 417.06 ms in get_data(17, 12)
# DEBUG:analysis:417.06 ms in get_data(17, 12)
# 707.60 ms in get_probes(12)
# DEBUG:analysis:707.60 ms in get_probes(12)
#   1.20 s in load_gse( series_id platform_id..., 17)
# DEBUG:analysis:  1.20 s in load_gse( series_id platform_id..., 17)
# analysis.py:360: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   samples['subset'] = "NA"
# 296.47 ms in get_fold_change_analysis(<Gse GSE10064>)
# DEBUG:analysis:296.47 ms in get_fold_change_analysis(<Gse GSE10064>)
# Loading data for GSE13732, id = 973
# DEBUG:analysis:Loading data for GSE13732, id = 973
#   3.13 s in get_data(973, 4)
# DEBUG:analysis:  3.13 s in get_data(973, 4)
#   1.10 s in get_probes(4)
# DEBUG:analysis:  1.10 s in get_probes(4)
#   4.31 s in load_gse( series_id platform_id..., 973)
# DEBUG:analysis:  4.31 s in load_gse( series_id platform_id..., 973)
#   1.48 s in get_fold_change_analysis(<Gse GSE13732>)
# DEBUG:analysis:  1.48 s in get_fold_change_analysis(<Gse GSE13732>)
# Loading data for GSE14895, id = 1280
# DEBUG:analysis:Loading data for GSE14895, id = 1280
# 407.54 ms in get_data(1280, 9)
# DEBUG:analysis:407.54 ms in get_data(1280, 9)
# 469.82 ms in get_probes(9)
# DEBUG:analysis:469.82 ms in get_probes(9)
# 340.22 ms in get_data(1280, 2)
# DEBUG:analysis:340.22 ms in get_data(1280, 2)
# 337.85 ms in get_probes(2)
# DEBUG:analysis:337.85 ms in get_probes(2)
#   1.66 s in load_gse( series_id platform_id..., 1280)
# DEBUG:analysis:  1.66 s in load_gse( series_id platform_id..., 1280)
# 443.20 ms in get_fold_change_analysis(<Gse GSE14895>)
# DEBUG:analysis:443.20 ms in get_fold_change_analysis(<Gse GSE14895>)
# Loading data for GSE16461, id = 1688
# DEBUG:analysis:Loading data for GSE16461, id = 1688
# 499.49 ms in get_data(1688, 4)
# DEBUG:analysis:499.49 ms in get_data(1688, 4)
# 872.84 ms in get_probes(4)
# DEBUG:analysis:872.84 ms in get_probes(4)
#   1.45 s in load_gse( series_id platform_id..., 1688)
# DEBUG:analysis:  1.45 s in load_gse( series_id platform_id..., 1688)
# 388.80 ms in get_fold_change_analysis(<Gse GSE16461>)
# DEBUG:analysis:388.80 ms in get_fold_change_analysis(<Gse GSE16461>)
# Loading data for GSE17048, id = 1837
# DEBUG:analysis:Loading data for GSE17048, id = 1837
#   2.36 s in get_data(1837, 389)
# DEBUG:analysis:  2.36 s in get_data(1837, 389)
# 872.41 ms in get_probes(389)
# DEBUG:analysis:872.41 ms in get_probes(389)
#   3.31 s in load_gse( series_id platform_id..., 1837)
# DEBUG:analysis:  3.31 s in load_gse( series_id platform_id..., 1837)
#   1.27 s in get_fold_change_analysis(<Gse GSE17048>)
# DEBUG:analysis:  1.27 s in get_fold_change_analysis(<Gse GSE17048>)
# Loading data for GSE17393, id = 1917
# DEBUG:analysis:Loading data for GSE17393, id = 1917
# 298.03 ms in get_data(1917, 9)
# DEBUG:analysis:298.03 ms in get_data(1917, 9)
# 383.49 ms in get_probes(9)
# DEBUG:analysis:383.49 ms in get_probes(9)
# 757.03 ms in load_gse( series_id platform_id..., 1917)
# DEBUG:analysis:757.03 ms in load_gse( series_id platform_id..., 1917)
# 183.63 ms in get_fold_change_analysis(<Gse GSE17393>)
# DEBUG:analysis:183.63 ms in get_fold_change_analysis(<Gse GSE17393>)
# Loading data for GSE17449, id = 1929
# DEBUG:analysis:Loading data for GSE17449, id = 1929
# 426.55 ms in get_data(1929, 9)
# DEBUG:analysis:426.55 ms in get_data(1929, 9)
# 309.34 ms in get_probes(9)
# DEBUG:analysis:309.34 ms in get_probes(9)
# 808.61 ms in load_gse( series_id platform_id..., 1929)
# DEBUG:analysis:808.61 ms in load_gse( series_id platform_id..., 1929)
# 222.71 ms in get_fold_change_analysis(<Gse GSE17449>)
# DEBUG:analysis:222.71 ms in get_fold_change_analysis(<Gse GSE17449>)
# Loading data for GSE21942, id = 3050
# DEBUG:analysis:Loading data for GSE21942, id = 3050
# 553.42 ms in get_data(3050, 4)
# DEBUG:analysis:553.42 ms in get_data(3050, 4)
# 537.30 ms in get_probes(4)
# DEBUG:analysis:537.30 ms in get_probes(4)
#   1.16 s in load_gse( series_id platform_id..., 3050)
# DEBUG:analysis:  1.16 s in load_gse( series_id platform_id..., 3050)
# 502.57 ms in get_fold_change_analysis(<Gse GSE21942>)
# DEBUG:analysis:502.57 ms in get_fold_change_analysis(<Gse GSE21942>)
# Loading data for GSE23832, id = 3564
# DEBUG:analysis:Loading data for GSE23832, id = 3564
# 249.10 ms in get_data(3564, 283)
# DEBUG:analysis:249.10 ms in get_data(3564, 283)
# 334.74 ms in get_probes(283)
# DEBUG:analysis:334.74 ms in get_probes(283)
# 655.86 ms in load_gse( series_id platform_id..., 3564)
# DEBUG:analysis:655.86 ms in load_gse( series_id platform_id..., 3564)
# 149.19 ms in get_fold_change_analysis(<Gse GSE23832>)
# DEBUG:analysis:149.19 ms in get_fold_change_analysis(<Gse GSE23832>)
# Loading data for GSE26484, id = 4227
# DEBUG:analysis:Loading data for GSE26484, id = 4227
# 364.25 ms in get_data(4227, 4)
# DEBUG:analysis:364.25 ms in get_data(4227, 4)
# 412.22 ms in get_probes(4)
# DEBUG:analysis:412.22 ms in get_probes(4)
# 850.28 ms in load_gse( series_id platform_id..., 4227)
# DEBUG:analysis:850.28 ms in load_gse( series_id platform_id..., 4227)
# 342.46 ms in get_fold_change_analysis(<Gse GSE26484>)
# DEBUG:analysis:342.46 ms in get_fold_change_analysis(<Gse GSE26484>)
# Loading data for GSE27688, id = 4537
# DEBUG:analysis:Loading data for GSE27688, id = 4537
# 563.25 ms in get_data(4537, 53)
# DEBUG:analysis:563.25 ms in get_data(4537, 53)
# 601.22 ms in get_probes(53)
# DEBUG:analysis:601.22 ms in get_probes(53)
#   1.24 s in load_gse( series_id platform_id..., 4537)
# DEBUG:analysis:  1.24 s in load_gse( series_id platform_id..., 4537)
# 420.23 ms in get_fold_change_analysis(<Gse GSE27688>)
# DEBUG:analysis:420.23 ms in get_fold_change_analysis(<Gse GSE27688>)
# Loading data for GSE32645, id = 5766
# DEBUG:analysis:Loading data for GSE32645, id = 5766
# 436.79 ms in get_data(5766, 10)
# DEBUG:analysis:436.79 ms in get_data(5766, 10)
# 733.91 ms in get_probes(10)
# DEBUG:analysis:733.91 ms in get_probes(10)
#   1.25 s in load_gse( series_id platform_id..., 5766)
# DEBUG:analysis:  1.25 s in load_gse( series_id platform_id..., 5766)
# 263.24 ms in get_fold_change_analysis(<Gse GSE32645>)
# DEBUG:analysis:263.24 ms in get_fold_change_analysis(<Gse GSE32645>)
# Loading data for GSE32915, id = 5810
# DEBUG:analysis:Loading data for GSE32915, id = 5810
# /Users/dex/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
# 456.41 ms in get_data(5810, 10)
# DEBUG:analysis:456.41 ms in get_data(5810, 10)
# 425.62 ms in get_probes(10)
# DEBUG:analysis:425.62 ms in get_probes(10)
# 956.43 ms in load_gse( series_id platform_id..., 5810)
# DEBUG:analysis:956.43 ms in load_gse( series_id platform_id..., 5810)
# 309.04 ms in get_fold_change_analysis(<Gse GSE32915>)
# DEBUG:analysis:309.04 ms in get_fold_change_analysis(<Gse GSE32915>)
# Loading data for GSE32988, id = 5831
# DEBUG:analysis:Loading data for GSE32988, id = 5831
#   1.16 s in get_data(5831, 53)
# DEBUG:analysis:  1.16 s in get_data(5831, 53)
# 467.55 ms in get_probes(53)
# DEBUG:analysis:467.55 ms in get_probes(53)
#   1.71 s in load_gse( series_id platform_id..., 5831)
# DEBUG:analysis:  1.71 s in load_gse( series_id platform_id..., 5831)
# 593.42 ms in get_fold_change_analysis(<Gse GSE32988>)
# DEBUG:analysis:593.42 ms in get_fold_change_analysis(<Gse GSE32988>)
# Loading data for GSE41848, id = 7884
# DEBUG:analysis:Loading data for GSE41848, id = 7884
#   2.24 s in get_data(7884, 1289)
# DEBUG:analysis:  2.24 s in get_data(7884, 1289)
#  33.71 ms in get_probes(1289)
# DEBUG:analysis: 33.71 ms in get_probes(1289)
#   2.34 s in load_gse( series_id platform_id..., 7884)
# DEBUG:analysis:  2.34 s in load_gse( series_id platform_id..., 7884)
#   1.05 s in get_fold_change_analysis(<Gse GSE41848>)
# DEBUG:analysis:  1.05 s in get_fold_change_analysis(<Gse GSE41848>)
# Loading data for GSE41849, id = 7885
# DEBUG:analysis:Loading data for GSE41849, id = 7885
#   1.14 s in get_data(7885, 1289)
# DEBUG:analysis:  1.14 s in get_data(7885, 1289)
#  36.09 ms in get_probes(1289)
# DEBUG:analysis: 36.09 ms in get_probes(1289)
#   1.25 s in load_gse( series_id platform_id..., 7885)
# DEBUG:analysis:  1.25 s in load_gse( series_id platform_id..., 7885)
# 547.69 ms in get_fold_change_analysis(<Gse GSE41849>)
# DEBUG:analysis:547.69 ms in get_fold_change_analysis(<Gse GSE41849>)
# Loading data for GSE41850, id = 7887
# DEBUG:analysis:Loading data for GSE41850, id = 7887
#   8.63 s in get_data(7887, 1289)
# DEBUG:analysis:  8.63 s in get_data(7887, 1289)
#  33.32 ms in get_probes(1289)
# DEBUG:analysis: 33.32 ms in get_probes(1289)
#   8.74 s in load_gse( series_id platform_id..., 7887)
# DEBUG:analysis:  8.74 s in load_gse( series_id platform_id..., 7887)
#   4.36 s in get_fold_change_analysis(<Gse GSE41850>)
# DEBUG:analysis:  4.36 s in get_fold_change_analysis(<Gse GSE41850>)
# Loading data for GSE41890, id = 7897
# DEBUG:analysis:Loading data for GSE41890, id = 7897
#   1.10 s in get_data(7897, 283)
# DEBUG:analysis:  1.10 s in get_data(7897, 283)
# 738.76 ms in get_probes(283)
# DEBUG:analysis:738.76 ms in get_probes(283)
#   1.92 s in load_gse( series_id platform_id..., 7897)
# DEBUG:analysis:  1.92 s in load_gse( series_id platform_id..., 7897)
# 623.47 ms in get_fold_change_analysis(<Gse GSE41890>)
# DEBUG:analysis:623.47 ms in get_fold_change_analysis(<Gse GSE41890>)
# Loading data for GSE43591, id = 8314
# DEBUG:analysis:Loading data for GSE43591, id = 8314
# 713.43 ms in get_data(8314, 4)
# DEBUG:analysis:713.43 ms in get_data(8314, 4)
# 488.20 ms in get_probes(4)
# DEBUG:analysis:488.20 ms in get_probes(4)
#   1.28 s in load_gse( series_id platform_id..., 8314)
# DEBUG:analysis:  1.28 s in load_gse( series_id platform_id..., 8314)
# 494.34 ms in get_fold_change_analysis(<Gse GSE43591>)
# DEBUG:analysis:494.34 ms in get_fold_change_analysis(<Gse GSE43591>)
# Loading data for GSE37750, id = 12030
# DEBUG:analysis:Loading data for GSE37750, id = 12030
# 830.72 ms in get_data(12030, 4)
# DEBUG:analysis:830.72 ms in get_data(12030, 4)
# 498.15 ms in get_probes(4)
# DEBUG:analysis:498.15 ms in get_probes(4)
#   1.40 s in load_gse( series_id platform_id..., 12030)
# DEBUG:analysis:  1.40 s in load_gse( series_id platform_id..., 12030)
# 531.33 ms in get_fold_change_analysis(<Gse GSE37750>)
# DEBUG:analysis:531.33 ms in get_fold_change_analysis(<Gse GSE37750>)
# Loading data for GSE59085, id = 12788
# DEBUG:analysis:Loading data for GSE59085, id = 12788
# 768.05 ms in get_data(12788, 4)
# DEBUG:analysis:768.05 ms in get_data(12788, 4)
# 530.70 ms in get_probes(4)
# DEBUG:analysis:530.70 ms in get_probes(4)
#   1.37 s in load_gse( series_id platform_id..., 12788)
# DEBUG:analysis:  1.37 s in load_gse( series_id platform_id..., 12788)
# 502.74 ms in get_fold_change_analysis(<Gse GSE59085>)
# DEBUG:analysis:502.74 ms in get_fold_change_analysis(<Gse GSE59085>)
#  55.78 s in Load/fold for test
# DEBUG:analysis: 55.78 s in Load/fold for test
# Meta-Analyzing test
# INFO:analysis:Meta-Analyzing test
#  58.35 s in Meta analysis for test
# DEBUG:analysis: 58.35 s in Meta analysis for test
# DONE test analysis
# INFO:analysis:DONE test analysis
# 114.81 s in perform_analysis(analysis={'analysis_name': 'tes...)
# DEBUG:analysis:114.81 s in perform_analysis(analysis={'analysis_name': 'tes...)
